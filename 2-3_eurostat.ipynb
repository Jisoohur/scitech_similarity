# %%
import pandas as pd 
employment = pd.read_csv('eurostat_employment.csv')
# keep only rows where 'wstatus' column is 'EMP' and 'nace_r2' column is 'TOTAL'
employment = employment[(employment['wstatus'] == 'EMP') & (employment['nace_r2'] == 'TOTAL')]
employment.head()
# Out:
#                            DATAFLOW        LAST UPDATE freq unit wstatus  \
# 424842  ESTAT:NAMA_10R_3EMPERS(1.0)  13/03/24 23:00:00    A  THS     EMP
# 424843  ESTAT:NAMA_10R_3EMPERS(1.0)  13/03/24 23:00:00    A  THS     EMP
# 424844  ESTAT:NAMA_10R_3EMPERS(1.0)  13/03/24 23:00:00    A  THS     EMP
# 424845  ESTAT:NAMA_10R_3EMPERS(1.0)  13/03/24 23:00:00    A  THS     EMP
# 424846  ESTAT:NAMA_10R_3EMPERS(1.0)  13/03/24 23:00:00    A  THS     EMP
#
#        nace_r2 geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 424842   TOTAL  AT         2000     3755.0      NaN
# 424843   TOTAL  AT         2001     3782.0      NaN
# 424844   TOTAL  AT         2002     3778.4      NaN
# 424845   TOTAL  AT         2003     3803.0      NaN
# 424846   TOTAL  AT         2004     3826.8      NaN

# %%
employment = employment[['geo', 'TIME_PERIOD', 'OBS_VALUE']]

# keep rows where 'geo' is comprised of 5 characters
employment = employment[employment['geo'].str.len() == 4]

# change column names 
employment.columns = ['eu_nuts_id', 'year', 'eurostat_employment']

# drop duplicates 
employment = employment.drop_duplicates()
employment
# Out:
#        eu_nuts_id  year  eurostat_employment
# 424888       AT11  2000               101.10
# 424889       AT11  2001               101.40
# 424890       AT11  2002               102.50
# 424891       AT11  2003               103.80
# 424892       AT11  2004               103.90
# ...           ...   ...                  ...
# 461216       SK04  2018               573.53
# 461217       SK04  2019               583.97
# 461218       SK04  2020               573.73
# 461219       SK04  2021               567.78
# 461220       SK04  2022               577.91
#
# [6219 rows x 3 columns]

# %%
gdp = pd.read_csv('eurostat_gdp.csv')

# keep only rows where 'unit' column is 'EUR_HAB' 
gdp = gdp[gdp['unit'] == 'EUR_HAB']
gdp
# Out:
#                        DATAFLOW        LAST UPDATE freq     unit    geo  \
# 0      ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB     AL
# 1      ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB     AL
# 2      ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB     AL
# 3      ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB     AL
# 4      ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB     AL
# ...                         ...                ...  ...      ...    ...
# 37753  ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB  TRC34
# 37754  ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB  TRC34
# 37755  ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB  TRC34
# 37756  ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB  TRC34
# 37757  ESTAT:NAMA_10R_3GDP(1.0)  19/02/24 23:00:00    A  EUR_HAB  TRC34
#
#        TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0             2008     3000.0      NaN
# 1             2009     3000.0      NaN
# 2             2010     3100.0      NaN
# 3             2011     3200.0      NaN
# 4             2012     3300.0      NaN
# ...            ...        ...      ...
# 37753         2018     3500.0      NaN
# 37754         2019     4200.0      NaN
# 37755         2020     4100.0      NaN
# 37756         2021     3800.0      NaN
# 37757         2022     4600.0      NaN
#
# [37758 rows x 8 columns]

# %%
gdp = gdp[['geo', 'TIME_PERIOD', 'OBS_VALUE']]
gdp = gdp[gdp['geo'].str.len() == 4]

# change column names
gdp.columns = ['eu_nuts_id', 'year', 'eurostat_GDP']

# drop duplicates
gdp = gdp.drop_duplicates()
gdp
# Out:
#       eu_nuts_id  year  eurostat_GDP
# 28          AL01  2008        2300.0
# 29          AL01  2009        2400.0
# 30          AL01  2010        2600.0
# 31          AL01  2011        2600.0
# 32          AL01  2012        2700.0
# ...          ...   ...           ...
# 37677       TRC3  2018        4000.0
# 37678       TRC3  2019        4200.0
# 37679       TRC3  2020        4000.0
# 37680       TRC3  2021        4100.0
# 37681       TRC3  2022        5200.0
#
# [6326 rows x 3 columns]

# %%
check = gdp[gdp['eu_nuts_id'] == 'AT11']
check.head(50)
# Out:
#     eu_nuts_id  year  eurostat_GDP
# 284       AT11  2000       17400.0
# 285       AT11  2001       17900.0
# 286       AT11  2002       18800.0
# 287       AT11  2003       19300.0
# 288       AT11  2004       20300.0
# 289       AT11  2005       20500.0
# 290       AT11  2006       21100.0
# 291       AT11  2007       22400.0
# 292       AT11  2008       22700.0
# 293       AT11  2009       22700.0
# 294       AT11  2010       23600.0
# 295       AT11  2011       24600.0
# 296       AT11  2012       25700.0
# 297       AT11  2013       26300.0
# 298       AT11  2014       26900.0
# 299       AT11  2015       27800.0
# 300       AT11  2016       28600.0
# 301       AT11  2017       29800.0
# 302       AT11  2018       30600.0
# 303       AT11  2019       31400.0
# 304       AT11  2020       30300.0
# 305       AT11  2021       32000.0
# 306       AT11  2022       34900.0

# %%
# merge the two dataframes
eurostat = pd.merge(employment, gdp, on=['eu_nuts_id', 'year'], how = 'outer')
eurostat
# Out:
#      eu_nuts_id  year  eurostat_employment  eurostat_GDP
# 0          AL01  2008                  NaN        2300.0
# 1          AL01  2009                  NaN        2400.0
# 2          AL01  2010                  NaN        2600.0
# 3          AL01  2011                  NaN        2600.0
# 4          AL01  2012                  NaN        2700.0
# ...         ...   ...                  ...           ...
# 6822       TRC3  2018                  NaN        4000.0
# 6823       TRC3  2019                  NaN        4200.0
# 6824       TRC3  2020                  NaN        4000.0
# 6825       TRC3  2021                  NaN        4100.0
# 6826       TRC3  2022                  NaN        5200.0
#
# [6827 rows x 4 columns]

# %%
# slice the data to only include data from 2010 to 2021
eurostat = eurostat[(eurostat['year'] >= 1980) & (eurostat['year'] <= 2021)]
eurostat['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        1995, 1996, 1997, 1998, 1999], dtype=int64)

# %%
# create 'period' column 
def assign_period(pubyear):
    if 1981 <= pubyear <= 1985:
        return 1
    elif 1986 <= pubyear <= 1990:
        return 2 
    elif 1991 <= pubyear <= 1995:
        return 3 
    elif 1996 <= pubyear <= 2000:
        return 4
    elif 2001 <= pubyear <= 2005:
        return 5
    elif 2006 <= pubyear <= 2010:
        return 6
    elif 2011 <= pubyear <= 2015:
        return 7
    elif 2016 <= pubyear <= 2020:
        return 8
    else:
        return 0 
    
eurostat['period'] = eurostat['year'].apply(assign_period)
eurostat.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32892\3620635268.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eurostat['period'] = eurostat['year'].apply(assign_period)
#   eu_nuts_id  year  eurostat_employment  eurostat_GDP  period
# 0       AL01  2008                  NaN        2300.0       6
# 1       AL01  2009                  NaN        2400.0       6
# 2       AL01  2010                  NaN        2600.0       6
# 3       AL01  2011                  NaN        2600.0       7
# 4       AL01  2012                  NaN        2700.0       7

# %%
# drop 'year' column
eurostat.drop('year', axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32892\3831359445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eurostat.drop('year', axis=1, inplace=True)

# %%
# check NaN values
eurostat.isnull().sum()
# Out:
# eu_nuts_id               0
# eurostat_employment    581
# eurostat_GDP           489
# period                   0
# dtype: int64

# %%
# group by 'eu_nuts_id' and 'period' columns, calculate the mean 
eurostat = eurostat.groupby(['eu_nuts_id', 'period']).mean().reset_index()
eurostat
# Out:
#      eu_nuts_id  period  eurostat_employment  eurostat_GDP
# 0          AL01       0                  NaN   4300.000000
# 1          AL01       6                  NaN   2433.333333
# 2          AL01       7                  NaN   2720.000000
# 3          AL01       8                  NaN   3520.000000
# 4          AL02       0                  NaN   6500.000000
# ...         ...     ...                  ...           ...
# 1769       TRC3       0                  NaN   4100.000000
# 1770       TRC3       5                  NaN   2250.000000
# 1771       TRC3       6                  NaN   3120.000000
# 1772       TRC3       7                  NaN   4420.000000
# 1773       TRC3       8                  NaN   4300.000000
#
# [1774 rows x 4 columns]

# %%
eurostat.isnull().sum()
# Out:
# eu_nuts_id               0
# period                   0
# eurostat_employment    163
# eurostat_GDP           119
# dtype: int64

# %%
eurostat.to_csv('eurostat_merged_data.csv', index=False)
